# %%
import cv2
from glob import glob
from pathlib import Path

from utils import plot
import torch
import torchvision.transforms as transforms

# %%
model = torch.load('clip_model.pt')
model.model.eval()
# Out:
# CLIP(
#   (visual): VisionTransformer(
#     (conv1): Conv2d(3, 768, kernel_size=(32, 32), stride=(32, 32), bias=False)
#     (ln_pre): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (transformer): Transformer(
#       (resblocks): Sequential(
#         (0): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): _LinearWithBias(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): _LinearWithBias(in_features=768, out_features=768, bias=True)
# ...

# %%
image_pathes = glob('./data/*.jpg')
image_pathes += glob('./data/*.png')
image_pathes[:2]
# Out:
# ['./data\\0_Wrexham-brawl1.jpg', './data\\236471216.jpg.gallery.jpg']

# %%
print(model.labels)
for i, image_path in enumerate(image_pathes):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    label = model.predict(image)['label']
    # Get the list of classes
    confidence = model.predict(image)['confidence']
    print(confidence)
    plot(image=image, title=label)
# Out:
# ---------------------------------------------------------------------------
# ModuleAttributeError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2716\577508526.py in <module>
# ----> 1 print(model.labels)
#       2 for i, image_path in enumerate(image_pathes):
#       3     image = cv2.imread(image_path)
#       4     image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#       5     label = model.predict(image)['label']
#
# c:\projects\final_year_project\violence-detection\venv\lib\site-packages\torch\nn\modules\module.py in __getattr__(self, name)
#     777                 return modules[name]
#     778         raise ModuleAttributeError("'{}' object has no attribute '{}'".format(
# --> 779             type(self).__name__, name))
#     780
#     781     def __setattr__(self, name: str, value: Union[Tensor, 'Module']) -> None:
#
# ModuleAttributeError: 'CLIP' object has no attribute 'labels'

# %%
import cv2 
  
  
cap = cv2.VideoCapture('./data/cars.mp4') 
  
while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Preprocess the frame
    # ... (use appropriate preprocessing based on your model)

    # Convert the frame to a PyTorch tensor
    transform = transforms.Compose([
        transforms.ToPILImage(),
        transforms.Resize((224, 224)),  # Adjust size according to your model's input size
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    input_tensor = transform(frame).unsqueeze(0)

    # Make prediction
    with torch.no_grad():
        output = model.predict(input_tensor)['label']


    # Get the predicted class
    _, predicted_class = torch.max(output, 1)

    # Display the classification result on the frame
    cv2.putText(frame, f"Class: {predicted_class.item()}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    # Display the frame
    cv2.imshow('Video Classification', frame)

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture object
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2716\3133088404.py in <module>
#      24     # Make prediction
#      25     with torch.no_grad():
# ---> 26         output = model.predict(input_tensor)['label']
#      27
#      28
#
# c:\projects\final_year_project\violence-detection\venv\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ---> 26                 return func(*args, **kwargs)
#      27         return cast(F, decorate_context)
#      28
#
# c:\projects\final_year_project\violence-detection\model.py in predict(self, image)
#      74                     thus you may see low conf. values for right predictions.
#      75         '''
# ---> 76         tf_image = self.transform_image(image)
# ...

# %%
import cv2 
  
  
cap = cv2.VideoCapture('./data/cars.mp4') 


while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Your image processing and classification code here
    prediction = model.predict(frame)
    label = prediction['label']
    conf = prediction['confidence']
    frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
    frame = cv2.putText(frame, label.title(), 
                            (0, 100), 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, 
                            (0, 0, 255), 2)
    # Display the frame
    cv2.imshow('Real-time Image Classification', frame)

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture object
cap.release()
cv2.destroyAllWindows()
